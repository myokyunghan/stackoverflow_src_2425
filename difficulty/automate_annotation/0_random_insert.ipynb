# %%
import lib.annotation.Sample_Insert as si
from datetime import datetime, timedelta
# Out:
# INFO 01-05 12:57:56 [__init__.py:216] Automatically detected platform cuda.

# %%
def return_date_list(stday) :
    start_date = datetime(2021, 11, 30)
    end_date = datetime(2024, 12, 1)

    # 결과 날짜를 저장할 리스트
    dates = []

    # 현재 날짜를 시작 날짜로 설정
    current_date = start_date

    while current_date <= end_date:
        chk_date = (datetime(current_date.year, current_date.month, 1) + timedelta(days=stday-1))
        if chk_date <= end_date :
            dates.append([
                            (datetime(current_date.year, current_date.month, 1) + timedelta(days=stday-1)).strftime("%Y-%m-%d"), 
                            (datetime(current_date.year, current_date.month, 1) + timedelta(days=stday)).strftime("%Y-%m-%d")
                        ])
            # 다음 달로 이동
            year = current_date.year
            month = current_date.month + 1
            if month > 12:
                month = 1
                year += 1
            current_date = datetime(year, month, 1)
        else :
            break

    return dates

# %%
date = return_date_list(5)
# date_10 = return_date_list(10)
# date_15 = return_date_list(15)
# date_20 = return_date_list(20)
# date_25 = return_date_list(25)
# date = return_date_list(30)

# %%
date
# Out:
# [['2021-11-05', '2021-11-06'],
#  ['2021-12-05', '2021-12-06'],
#  ['2022-01-05', '2022-01-06'],
#  ['2022-02-05', '2022-02-06'],
#  ['2022-03-05', '2022-03-06'],
#  ['2022-04-05', '2022-04-06'],
#  ['2022-05-05', '2022-05-06'],
#  ['2022-06-05', '2022-06-06'],
#  ['2022-07-05', '2022-07-06'],
#  ['2022-08-05', '2022-08-06'],
#  ['2022-09-05', '2022-09-06'],
#  ['2022-10-05', '2022-10-06'],
#  ['2022-11-05', '2022-11-06'],
#  ['2022-12-05', '2022-12-06'],
#  ['2023-01-05', '2023-01-06'],
#  ['2023-02-05', '2023-02-06'],
#  ['2023-03-05', '2023-03-06'],
#  ['2023-04-05', '2023-04-06'],
#  ['2023-05-05', '2023-05-06'],
#  ['2023-06-05', '2023-06-06'],
#  ['2023-07-05', '2023-07-06'],
#  ['2023-08-05', '2023-08-06'],
#  ['2023-09-05', '2023-09-06'],
#  ['2023-10-05', '2023-10-06'],
#  ['2023-11-05', '2023-11-06'],
#  ['2023-12-05', '2023-12-06'],
#  ['2024-01-05', '2024-01-06'],
#  ['2024-02-05', '2024-02-06'],
#  ['2024-03-05', '2024-03-06'],
#  ['2024-04-05', '2024-04-06'],
#  ['2024-05-05', '2024-05-06'],
#  ['2024-06-05', '2024-06-06'],
#  ['2024-07-05', '2024-07-06'],
#  ['2024-08-05', '2024-08-06'],
#  ['2024-09-05', '2024-09-06'],
#  ['2024-10-05', '2024-10-06'],
#  ['2024-11-05', '2024-11-06']]

69858161], [50250, '2021-11-05', 69854953], [50250, '2021-11-05', 69854942], [50250, '2021-11-05', 69849956], [50250, '2021-11-05', 69854382], [50250, '2021-11-05', 69856881], [50250, '2021-11-05', 69852791], [50250, '2021-11-05', 69852831], [50250, '2021-11-05', 69855511], [50250, '2021-11-05', 69855985], [50250, '2021-11-05', 69847365], [50250, '2021-11-05', 69850420], [50250, '2021-11-05', 69848807], [50250, '2021-11-05', 69850131], [50250, '2021-11-05', 69856278], [50250, '2021-11-05', 69855148], [50250, '2021-11-05', 69858961], [50250, '2021-11-05', 69857960], [50250, '2021-11-05', 69849585], [50250, '2021-11-05', 69859365], [50250, '2021-11-05', 69854878], [50250, '2021-11-05', 69860181], [50250, '2021-11-05', 69848180], [50250, '2021-11-05', 69859734], [50250, '2021-11-05', 69853030], [50250, '2021-11-05', 69860322], [50250, '2021-11-05', 69858625], [50250, '2021-11-05', 69857873], [50250, '2021-11-05', 69854096], [50250, '2021-11-05', 69848556], [50250, '2021-11-05', 69856907], [50250, '2021-11-05', 69858335], [50250, '2021-11-05', 69855962], [50250, '2021-11-05', 69856482], [50250, '2021-11-05', 69856460], [50250, '2021-11-05', 69848635]]
# Error :  relation "public_for_2324.tt_posts_difficulty_target" does not exist
# LINE 1: INSERT INTO public_for_2324.tt_posts_difficulty_target  VALU...
#                     ^
#
# sample_insert
# sample_insert> get_id_list
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 num_of_date = int(date[0][0].split('-')[2])
#       3 sample_insert = si.Sample_Insert(st_dt, end_dt, 100, 1, '1', num_of_date)
# ----> 4 sample_insert.insert_sample()
#
# File ~/sopjt/git/stackoverflow_src_2425/lib/annotation/Sample_Insert.py:95, in Sample_Insert.insert_sample(self)
#      92 def insert_sample(self):
#      93     print("sample_insert")
# ---> 95     p_id_df = self.get_id_list(self.posttype, self.st_dt, self.end_dt)
#      96     dt_list = list(p_id_df['creationdate'].unique())
#      98     print("sample_insert > create connection")
#
# File ~/sopjt/git/stackoverflow_src_2425/lib/annotation/Sample_Insert.py:31, in Sample_Insert.get_id_list(self, posttype, st_dt, end_dt)
#      20 q_sql = """select to_char(a.creationdate, 'yyyy-mm-dd') as creationdate,
#      21                 a.id
#      22             from posts a
#    (...)
#      28                     where a.id = x.id)
#      29     """
#      30 try:
# ---> 31     cur.execute(q_sql.format(posttype, st_dt, end_dt))
#      32     rows = cur.fetchall()
#      34 except psycopg2.DatabaseError as db_err:
#
# InterfaceError: cursor already closed

# %% [markdown]
# If there is no pattern of num of date

# %%
# sample_insert = si.Sample_Insert('2022-11-29', '2022-11-30', 30, 1, '1', 1111)
# sample_insert.insert_sample()
