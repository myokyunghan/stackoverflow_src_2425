# %% [markdown]
# # Experimental test 2
#
# * vllm기준으로 accuracy와 f1 score를 테스트
#     * fewshot 개수 : 3*3 = 9
#     * fewshot 테스트에 활용할 질문의 개수  : 30
#     * 소스코드 포함여부  : 'Y'
#     * 반복횟수 : 100회
#     * 시스템프롬프트 'sys_prompt10'
#     * self-consistency 횟수 : 5
#     * temperature : 0.01
#     * 엑셀버전 : 'ver7'
# * 이후 결과에 대해서 스코어 비교 진행

# %%
import lib.annotation.Self_Consistency as sc
# Out:
# INFO 01-04 16:14:39 [__init__.py:216] Automatically detected platform cuda.

# %%
from multiprocessing import Process
    
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature, excel_ver):

    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency(   llm_model
                            , few_shot_n
                            , test_n
                            , q_src_yn
                            , ver
                            , p_ver
                            , sc_num
                            , temperature
                            , excel_ver
                            , i)
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    process3 = Process(target=task, args=('v',              # llm_model
                                          3,                # few_shot_n
                                          40,                # test_n(# of question for test)
                                          'Y',              # q_src_yn 
                                          100,                # iteration num
                                          'sys_prompt10',   # prompt ver
                                          5,                # self-consistency number
                                          0.01,             # temperature
                                          'ver7'            # excel_verion
                                          ))
    process3.start()
    process3.join()
    print("모든 작업 완료")
# Out:
# Task v_3_40_Y_sys_prompt10_5 시작
# Task v_3_40_Y_sys_prompt10_5 실행 중: 0
# ./result/sc_v_result_3_40_Y_100_sys_prompt10_5_0.01_ver7_0.csv
# /usr/share/d_ollama/data/q_output_code_y_snapshot2.csv
# >>>>>>>>>>>>>>>>diff_idx : {'<Difficulty Level>0</Difficulty Level>': array([  8,   9,  11,  38,  47,  48,  52,  57,  58,  59,  62,  69,  75,
#         80,  81,  87,  88,  89,  90,  91,  96,  97, 101]), '<Difficulty Level>1</Difficulty Level>': array([  4,   5,   7,  10,  12,  14,  16,  20,  23,  26,  27,  30,  33,
#         35,  37,  39,  44,  51,  55,  63,  65,  66,  67,  68,  76,  78,
#         79,  83,  84,  92,  99, 100, 102]), '<Difficulty Level>2</Difficulty Level>': array([17, 18, 31, 42, 50, 54, 71, 86])}
# VLLM
# INFO 01-04 16:14:43 [utils.py:328] non-default args: {'tensor_parallel_size': 4, 'gpu_memory_utilization': 0.3, 'disable_log_stats': True, 'model': '/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct'}
# INFO 01-04 16:14:50 [__init__.py:742] Resolved architecture: LlamaForCausalLM
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 01-04 16:14:50 [__init__.py:1815] Using max model len 131072
# INFO 01-04 16:14:51 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:52 [core.py:654] Waiting for init message from front-end.
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:52 [core.py:76] Initializing a V1 LLM engine (v0.10.2) with config: model='/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct', speculative_config=None, tokenizer='/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=131072, download_dir=None, load_format=auto, tensor_parallel_size=4, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=27314) WARNING 01-04 16:14:52 [multiproc_worker_utils.py:273] Reducing Torch parallelism from 32 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:52 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0, 1, 2, 3], buffer_handle=(4, 16777216, 10, 'psm_cbe46003'), local_subscribe_addr='ipc:///tmp/67e489cf-562b-4f77-a69e-33b37cf085df', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:54 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_81abb44e'), local_subscribe_addr='ipc:///tmp/50fe8846-1c85-4a27-b753-124785bf1a71', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:54 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_2a5684fe'), local_subscribe_addr='ipc:///tmp/cccf57cb-83f2-4e6b-863a-4c5a9a3bfcfe', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:54 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_68407f2e'), local_subscribe_addr='ipc:///tmp/6dbed03f-204c-4116-b2d4-a49c765e9e41', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:54 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_f8931349'), local_subscribe_addr='ipc:///tmp/2701e8e7-b672-4e70-9969-8447f8f06060', remote_subscribe_addr=None, remote_addr_ipv6=False)
# [W104 16:14:55.479107578 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) INFO 01-04 16:14:56 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 01-04 16:14:56 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) INFO 01-04 16:14:56 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-04 16:14:56 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-04 16:14:56 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) INFO 01-04 16:14:56 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-04 16:14:56 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:56 [pynccl.py:70] vLLM is using nccl==2.27.3
# [W104 16:14:56.009798492 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W104 16:14:56.037587624 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W104 16:14:56.046516533 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3[Gloo] Rank  peer ranks. Expected number of connected peer ranks is : 32 is connected to
# 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) WARNING 01-04 16:14:56 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 16:14:56 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 16:14:56 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 16:14:56 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (EngineCore_DP0 pid=27314) INFO 01-04 16:14:56 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1, 2, 3], buffer_handle=(3, 4194304, 6, 'psm_13ac03f8'), local_subscribe_addr='ipc:///tmp/2dd2a5f6-3776-4260-95bf-4b7c5e4c427e', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) INFO 01-04 16:14:56 [parallel_state.py:1165] rank 0 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# INFO 01-04 16:14:56 [parallel_state.py:1165] rank 1 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# INFO 01-04 16:14:56 [parallel_state.py:1165] rank 2 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 2, EP rank 2
# INFO 01-04 16:14:56 [parallel_state.py:1165] rank 3 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 3, EP rank 3
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) WARNING 01-04 16:14:56 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=27314) WARNING 01-04 16:14:56 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-04 16:14:56 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-04 16:14:56 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:14:56 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:14:56 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:14:56 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:14:56 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:14:56 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:14:56 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:14:56 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:14:56 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) (EngineCore_DP0 pid=27314) INFO 01-04 16:14:57 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (Worker_TP2 pid=27681) INFO 01-04 16:14:57 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:14:57 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:14:57 [cuda.py:362] Using Flash Attention backend on V1 engine.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:14:57 [default_loader.py:268] Loading weights took 0.70 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:14:57 [default_loader.py:268] Loading weights took 0.70 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:14:57 [default_loader.py:268] Loading weights took 0.72 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:14:57 [default_loader.py:268] Loading weights took 0.75 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:14:58 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.925544 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) (EngineCore_DP0 pid=27314) INFO 01-04 16:14:58 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.926298 seconds
# (Worker_TP0 pid=27605) INFO 01-04 16:14:58 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.994841 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:14:58 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.953314 seconds
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:15:04 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_3_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:15:04 [backends.py:550] Dynamo bytecode transform time: 5.15 s
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:15:04 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_1_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:15:04 [backends.py:550] Dynamo bytecode transform time: 5.46 s
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:15:04 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:15:04 [backends.py:550] Dynamo bytecode transform time: 5.48 s
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:04 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_2_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:04 [backends.py:550] Dynamo bytecode transform time: 5.50 s
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:15:06 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.688 s
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:15:06 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.812 s
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:15:06 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.830 s
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:06 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.849 s
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:15:07 [monitor.py:34] torch.compile takes 5.15 s in total
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) (Worker_TP0 pid=27605) INFO 01-04 16:15:07 [monitor.py:34] torch.compile takes 5.46 s in total
# INFO 01-04 16:15:07 [monitor.py:34] torch.compile takes 5.48 s in total
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:07 [monitor.py:34] torch.compile takes 5.50 s in total
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:15:08 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:15:08 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:15:08 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:09 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:09 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:04<00:00, 15.72it/s]
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:15:14 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=27314) (Worker_TP1 pid=27658) INFO 01-04 16:15:14 [gpu_worker.py:391] Free memory on device (17.43/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=14476508160` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=27314) (Worker_TP0 pid=27605) INFO 01-04 16:15:14 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=27314) (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) (Worker_TP0 pid=27605) INFO 01-04 16:15:14 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# INFO 01-04 16:15:14 [gpu_worker.py:391] Free memory on device (18.21/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=15317203968` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=27314) (Worker_TP3 pid=27683) INFO 01-04 16:15:14 [gpu_worker.py:391] Free memory on device (23.11/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=20570831872` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:14 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=27314) (Worker_TP2 pid=27681) INFO 01-04 16:15:14 [gpu_worker.py:391] Free memory on device (22.23/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=19629210624` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=27314) INFO 01-04 16:15:14 [core.py:218] init engine (profile, create kv cache, warmup model) took 16.00 seconds
# INFO 01-04 16:15:15 [llm.py:295] Supported_tasks: ['generate']
# INFO 01-04 16:15:15 [__init__.py:36] No IOProcessor plugins requested by the model
# 0it [00:00, ?it/s]
# INFO 01-04 16:15:15 [chat_utils.py:538] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 1it [00:00,  1.15it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 2it [00:01,  1.29it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 3it [00:02,  1.55it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 4it [00:02,  1.79it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 5it [00:03,  1.71it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 6it [00:03,  1.82it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 7it [00:04,  1.60it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 8it [00:04,  1.61it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 9it [00:05,  1.79it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 10it [00:05,  1.83it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 11it [00:06,  1.83it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 12it [00:06,  2.08it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 13it [00:07,  2.17it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 14it [00:07,  2.15it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 15it [00:08,  2.12it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 16it [00:08,  1.81it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 17it [00:09,  1.77it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 18it [00:10,  1.77it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 19it [00:10,  1.89it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 20it [00:11,  1.90it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 21it [00:11,  1.97it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 22it [00:12,  1.93it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 23it [00:12,  1.88it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 24it [00:13,  1.82it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 25it [00:13,  1.85it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 26it [00:14,  1.83it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 27it [00:14,  1.93it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 28it [00:15,  1.84it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 29it [00:16,  1.67it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 30it [00:16,  1.63it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 31it [00:17,  1.82it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 32it [00:17,  1.85it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 33it [00:18,  1.84it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 34it [00:18,  1.75it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 35it [00:19,  1.84it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 36it [00:19,  1.85it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 37it [00:20,  1.79it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 38it [00:20,  1.86it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 39it [00:21,  1.68it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 40it [00:22,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 41it [00:22,  1.66it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 42it [00:23,  1.57it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 43it [00:24,  1.57it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 44it [00:24,  1.76it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 45it [00:25,  1.85it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 46it [00:25,  1.75it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 47it [00:26,  1.65it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 48it [00:27,  1.68it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 49it [00:27,  1.80it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 50it [00:28,  1.86it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 51it [00:28,  1.74it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 52it [00:29,  1.81it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 53it [00:29,  1.81it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 54it [00:30,  1.82it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 55it [00:30,  1.78it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 56it [00:31,  1.77it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 57it [00:32,  1.77it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 58it [00:32,  1.80it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 59it [00:33,  1.86it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 60it [00:33,  2.07it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 61it [00:33,  1.96it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 62it [00:34,  2.02it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 63it [00:35,  1.92it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 64it [00:35,  2.00it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 65it [00:36,  1.84it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 66it [00:36,  1.86it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 67it [00:37,  1.90it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 68it [00:37,  1.85it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 69it [00:38,  1.68it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 70it [00:38,  1.71it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 71it [00:39,  1.62it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 72it [00:40,  1.79it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 73it [00:40,  1.83it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 74it [00:41,  1.82it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 75it [00:41,  1.80it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 76it [00:42,  1.92it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 77it [00:42,  1.74it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 78it [00:43,  1.83it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 79it [00:43,  1.96it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 80it [00:44,  1.90it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 81it [00:45,  1.76it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 82it [00:45,  1.69it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 83it [00:46,  1.77it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 84it [00:46,  1.73it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 85it [00:47,  1.69it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 86it [00:47,  1.81it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 87it [00:48,  1.62it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 88it [00:49,  1.60it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 89it [00:49,  1.56it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 90it [00:50,  1.49it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 91it [00:51,  1.59it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 92it [00:51,  1.70it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 93it [00:52,  1.61it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 94it [00:53,  1.63it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 95it [00:53,  1.66it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 96it [00:54,  1.56it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 97it [00:54,  1.74it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 98it [00:55,  1.57it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 99it [00:56,  1.67it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 100it [00:56,  1.71it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 101it [00:57,  1.53it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 102it [00:58,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 103it [00:58,  1.36it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 104it [00:59,  1.36it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 105it [01:00,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 106it [01:01,  1.42it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 107it [01:01,  1.60it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 108it [01:02,  1.58it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 109it [01:02,  1.68it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 110it [01:03,  1.81it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 111it [01:03,  1.73it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 112it [01:04,  1.57it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 113it [01:05,  1.55it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 114it [01:06,  1.46it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 115it [01:06,  1.51it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 116it [01:07,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 117it [01:08,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 118it [01:08,  1.52it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 119it [01:09,  1.56it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 120it [01:09,  1.61it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 121it [01:10,  1.70it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 122it [01:11,  1.60it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 123it [01:11,  1.58it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 124it [01:12,  1.59it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 125it [01:12,  1.76it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 126it [01:13,  1.71it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 127it [01:14,  1.67it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 128it [01:14,  1.81it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 129it [01:15,  1.65it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 130it [01:15,  1.59it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 131it [01:16,  1.60it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 132it [01:17,  1.59it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 133it [01:17,  1.72it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 134it [01:17,  1.94it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 135it [01:18,  2.09it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 136it [01:18,  1.97it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 137it [01:19,  1.97it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 138it [01:20,  1.72it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# 195it [02:05,  1.16it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 196it [02:06,  1.23it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 197it [02:06,  1.38it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 198it [02:07,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 199it [02:07,  1.53it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 200it [02:08,  1.55it/s]
# Task v_3_40_Y_sys_prompt10_5 실행 중: 16
# ./result/sc_v_result_3_40_Y_100_sys_prompt10_5_0.01_ver7_16.csv
# /usr/share/d_ollama/data/q_output_code_y_snapshot2.csv
# >>>>>>>>>>>>>>>>diff_idx : {'<Difficulty Level>0</Difficulty Level>': array([  2,   8,  11,  21,  22,  38,  48,  57,  58,  59,  62,  70,  77,
#         81,  88,  89,  96, 101, 103]), '<Difficulty Level>1</Difficulty Level>': array([  0,   1,   4,   5,   6,  10,  12,  14,  15,  16,  20,  25,  26,
#         27,  30,  32,  34,  35,  36,  44,  45,  51,  56,  66,  67,  68,
#         72,  73,  74,  76,  83,  84, 102]), '<Difficulty Level>2</Difficulty Level>': array([17, 18, 24, 29, 31, 42, 50, 54, 71, 93, 94, 95])}
# VLLM
# INFO 01-04 16:53:30 [utils.py:328] non-default args: {'tensor_parallel_size': 4, 'gpu_memory_utilization': 0.3, 'disable_log_stats': True, 'model': '/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct'}
# INFO 01-04 16:53:30 [__init__.py:742] Resolved architecture: LlamaForCausalLM
# INFO 01-04 16:53:30 [__init__.py:1815] Using max model len 131072
# INFO 01-04 16:53:30 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:31 [core.py:654] Waiting for init message from front-end.
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:31 [core.py:76] Initializing a V1 LLM engine (v0.10.2) with config: model='/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct', speculative_config=None, tokenizer='/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=131072, download_dir=None, load_format=auto, tensor_parallel_size=4, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=669992) WARNING 01-04 16:53:31 [multiproc_worker_utils.py:273] Reducing Torch parallelism from 32 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:31 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0, 1, 2, 3], buffer_handle=(4, 16777216, 10, 'psm_2e15dc8b'), local_subscribe_addr='ipc:///tmp/74ce140c-b94e-4b26-b032-9103308bac1b', remote_subscribe_addr=None, remote_addr_ipv6=False)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:34 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_937d8b66'), local_subscribe_addr='ipc:///tmp/43c6401e-3407-4796-a237-7aeecc3e9962', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:34 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_f80f0acc'), local_subscribe_addr='ipc:///tmp/51c1c7ef-4757-4db6-b1da-7ad62a16cd37', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:34 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_c690df62'), local_subscribe_addr='ipc:///tmp/8c38c60a-9d7e-4ded-b867-71d43fbb9653', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:34 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_5ac70843'), local_subscribe_addr='ipc:///tmp/fc6abaaa-8564-4e94-8134-2546097e2f00', remote_subscribe_addr=None, remote_addr_ipv6=False)
# [W104 16:53:35.694701461 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W104 16:53:35.852946795 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 01-04 16:53:36 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 01-04 16:53:36 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-04 16:53:36 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-04 16:53:36 [pynccl.py:70] vLLM is using nccl==2.27.3
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [pynccl.py:70] vLLM is using nccl==2.27.3
# [W104 16:53:35.964904522 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W104 16:53:35.970459747 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank [Gloo] Rank 2 is connected to 33 is connected to  peer ranks. 3Expected number of connected peer ranks is :  peer ranks. 3Expected number of connected peer ranks is :
# 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) WARNING 01-04 16:53:36 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 16:53:36 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 16:53:36 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 16:53:36 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1, 2, 3], buffer_handle=(3, 4194304, 6, 'psm_c8e85738'), local_subscribe_addr='ipc:///tmp/48bfc43d-be95-413e-93f9-80ebf6fb2627', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [parallel_state.py:1165] rank 0 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) INFO 01-04 16:53:36 [parallel_state.py:1165] rank 1 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# INFO 01-04 16:53:36 [parallel_state.py:1165] rank 2 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 2, EP rank 2
# INFO 01-04 16:53:36 [parallel_state.py:1165] rank 3 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 3, EP rank 3
# (EngineCore_DP0 pid=669992) WARNING 01-04 16:53:36 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=669992) WARNING 01-04 16:53:36 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) WARNING 01-04 16:53:36 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-04 16:53:36 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (Worker_TP1 pid=670016) (Worker_TP0 pid=670014) INFO 01-04 16:53:36 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# INFO 01-04 16:53:36 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=669992) (Worker_TP2 pid=670018) INFO 01-04 16:53:36 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=669992) (Worker_TP3 pid=670020) INFO 01-04 16:53:36 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 00 is connected to
# 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=669992) (Worker_TP1 pid=670016) (EngineCore_DP0 pid=669992) INFO 01-04 16:53:37 [gpu_model_runner.py:2370] Loading model from scratch...
# (Worker_TP0 pid=670014) INFO 01-04 16:53:37 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=669992) (Worker_TP2 pid=670018) INFO 01-04 16:53:37 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=669992) (Worker_TP3 pid=670020) INFO 01-04 16:53:37 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (Worker_TP0 pid=670014) (Worker_TP1 pid=670016) INFO 01-04 16:53:37 [cuda.py:362] Using Flash Attention backend on V1 engine.
# INFO 01-04 16:53:37 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=669992) (EngineCore_DP0 pid=669992) (Worker_TP2 pid=670018) INFO 01-04 16:53:37 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (Worker_TP3 pid=670020) INFO 01-04 16:53:37 [cuda.py:362] Using Flash Attention backend on V1 engine.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=669992) (Worker_TP2 pid=670018) (EngineCore_DP0 pid=669992) INFO 01-04 16:53:38 [default_loader.py:268] Loading weights took 0.63 seconds
# (Worker_TP1 pid=670016) INFO 01-04 16:53:38 [default_loader.py:268] Loading weights took 0.67 seconds
# (EngineCore_DP0 pid=669992) (Worker_TP0 pid=670014) INFO 01-04 16:53:38 [default_loader.py:268] Loading weights took 0.73 seconds
# (EngineCore_DP0 pid=669992) (Worker_TP3 pid=670020) INFO 01-04 16:53:38 [default_loader.py:268] Loading weights took 0.67 seconds
# (EngineCore_DP0 pid=669992) (Worker_TP2 pid=670018) INFO 01-04 16:53:39 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.866993 seconds
# (EngineCore_DP0 pid=669992) (Worker_TP1 pid=670016) INFO 01-04 16:53:39 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.911001 seconds
# (EngineCore_DP0 pid=669992) (Worker_TP0 pid=670014) INFO 01-04 16:53:39 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.963382 seconds
# (EngineCore_DP0 pid=669992) (Worker_TP3 pid=670020) INFO 01-04 16:53:39 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 0.928915 seconds

# %% [markdown]
# <!-- Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt10', 3, 0.01, 'ver5'))
# Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt10', 3, 0.01, 'ver5'))
# Process(target=task, args=('l', 4, 10, 'Y', 10, 'sys_prompt10', 5, 0.01, 'ver5')) -->
