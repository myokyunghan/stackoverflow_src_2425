# %% [markdown]
# # Experimental test 2
#
# * vllm기준으로 accuracy와 f1 score를 테스트
# * few-shot테스트를 위해서 sc.Self_Consistency의 두번째 파라미터를 1, 2, 3, 4 로 변경하여 실험 수행
# * 이외의 파라미터는 고정
#     * fewshot 테스트에 활용할 질문의 개수  : 30
#     * 소스코드 포함여부  : 'Y'
#     * 반복횟수 : 100회
#     * 시스템프롬프트 'sys_prompt10'
#     * self-consistency 횟수 : 5
#     * temperature : 0.01
#     * 엑셀버전 : 'ver7'
# * 이후 결과에 대해서 스코어 비교 진행

# %%
import lib.annotation.Self_Consistency as sc
# Out:
# INFO 01-04 14:09:21 [__init__.py:216] Automatically detected platform cuda.

# %%
from multiprocessing import Process
    
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature, excel_ver):

    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency(   llm_model
                            , few_shot_n
                            , test_n
                            , q_src_yn
                            , ver
                            , p_ver
                            , sc_num
                            , temperature
                            , excel_ver
                            , i)
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    process3 = Process(target=task, args=('v',              # llm_model
                                          4,                # few_shot_n
                                          30,                # test_n(# of question for test)
                                          'Y',              # q_src_yn 
                                          100,                # iteration num
                                          'sys_prompt10',   # prompt ver
                                          5,                # self-consistency number
                                          0.01,             # temperature
                                          'ver7'            # excel_verion
                                          ))
    process3.start()
    process3.join()
    print("모든 작업 완료")
# Out:
# Task v_4_30_Y_sys_prompt10_5 시작
# Task v_4_30_Y_sys_prompt10_5 실행 중: 0
# ./result/sc_v_result_4_30_Y_100_sys_prompt10_5_0.01_ver7_0.csv
# /usr/share/d_ollama/data/q_output_code_y_snapshot2.csv
# >>>>>>>>>>>>>>>>diff_idx : {'<Difficulty Level>0</Difficulty Level>': array([  2,   8,  11,  21,  22,  38,  41,  47,  48,  53,  58,  59,  60,
#         62,  69,  70,  80,  81,  82,  87,  91,  96,  97, 101]), '<Difficulty Level>1</Difficulty Level>': array([  1,   3,   6,   7,  10,  12,  13,  14,  15,  19,  20,  25,  26,
#         27,  28,  30,  32,  33,  35,  36,  37,  39,  40,  43,  45,  51,
#         55,  56,  61,  65,  66,  67,  68,  72,  79,  83,  84,  92, 100,
#        102]), '<Difficulty Level>2</Difficulty Level>': array([17, 29, 31, 42, 49, 54, 71, 86, 94, 95])}
# VLLM
# INFO 01-04 14:09:24 [utils.py:328] non-default args: {'tensor_parallel_size': 4, 'gpu_memory_utilization': 0.3, 'disable_log_stats': True, 'model': '/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct'}
# INFO 01-04 14:09:32 [__init__.py:742] Resolved architecture: LlamaForCausalLM
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 01-04 14:09:32 [__init__.py:1815] Using max model len 131072
# INFO 01-04 14:09:33 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:33 [core.py:654] Waiting for init message from front-end.
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:33 [core.py:76] Initializing a V1 LLM engine (v0.10.2) with config: model='/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct', speculative_config=None, tokenizer='/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=131072, download_dir=None, load_format=auto, tensor_parallel_size=4, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=2427639) WARNING 01-04 14:09:33 [multiproc_worker_utils.py:273] Reducing Torch parallelism from 32 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:33 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0, 1, 2, 3], buffer_handle=(4, 16777216, 10, 'psm_456dcbdb'), local_subscribe_addr='ipc:///tmp/610d0803-c3cd-47fa-8014-4f708a303044', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:36 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_20e9ef69'), local_subscribe_addr='ipc:///tmp/dd85eb8a-8320-429a-bae6-fa225851348e', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 01-04 14:09:36 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_0206b941'), local_subscribe_addr='ipc:///tmp/a73deafb-70db-4889-b978-539cc6546489', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 01-04 14:09:36 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_57eaba5e'), local_subscribe_addr='ipc:///tmp/441e2c9c-e0c4-418a-b783-3987d926e1d6', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 01-04 14:09:36 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_97a733c2'), local_subscribe_addr='ipc:///tmp/2356b3c1-f464-471b-a7ad-d57c01a93cc6', remote_subscribe_addr=None, remote_addr_ipv6=False)
# [W104 14:09:37.505230524 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 01-04 14:09:38 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 01-04 14:09:38 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [pynccl.py:70] vLLM is using nccl==2.27.3
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-04 14:09:38 [pynccl.py:70] vLLM is using nccl==2.27.3
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [pynccl.py:70] vLLM is using nccl==2.27.3
# [W104 14:09:37.964449080 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W104 14:09:38.975487312 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W104 14:09:38.977928800 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) WARNING 01-04 14:09:38 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 14:09:38 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) WARNING 01-04 14:09:38 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-04 14:09:38 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1, 2, 3], buffer_handle=(3, 4194304, 6, 'psm_be25581e'), local_subscribe_addr='ipc:///tmp/d01b543f-6427-4c95-9d3f-8e406eda4ea5', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [parallel_state.py:1165] rank 0 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:38 [parallel_state.py:1165] rank 3 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 3, EP rank 3
# INFO 01-04 14:09:38 [parallel_state.py:1165] rank 2 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 2, EP rank 2
# INFO 01-04 14:09:38 [parallel_state.py:1165] rank 1 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) WARNING 01-04 14:09:38 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-04 14:09:38 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-04 14:09:38 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-04 14:09:38 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) INFO 01-04 14:09:38 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# INFO 01-04 14:09:38 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) INFO 01-04 14:09:38 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:09:38 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/Llama-3.2-3B-Instruct...
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:09:38 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:39 [gpu_model_runner.py:2370] Loading model from scratch...
# (Worker_TP1 pid=2427663) INFO 01-04 14:09:39 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:09:39 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) (Worker_TP3 pid=2427667) (Worker_TP2 pid=2427665) (Worker_TP0 pid=2427661) INFO 01-04 14:09:39 [cuda.py:362] Using Flash Attention backend on V1 engine.
# INFO 01-04 14:09:39 [cuda.py:362] Using Flash Attention backend on V1 engine.
# INFO 01-04 14:09:39 [cuda.py:362] Using Flash Attention backend on V1 engine.
# INFO 01-04 14:09:39 [cuda.py:362] Using Flash Attention backend on V1 engine.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) INFO 01-04 14:09:44 [default_loader.py:268] Loading weights took 4.91 seconds
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) (Worker_TP3 pid=2427667) (Worker_TP2 pid=2427665) INFO 01-04 14:09:44 [default_loader.py:268] Loading weights took 4.95 seconds
# INFO 01-04 14:09:44 [default_loader.py:268] Loading weights took 4.95 seconds
# INFO 01-04 14:09:44 [default_loader.py:268] Loading weights took 4.95 seconds
# (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) INFO 01-04 14:09:44 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 5.188383 seconds
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:09:44 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 5.243494 seconds
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) INFO 01-04 14:09:44 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 5.232866 seconds
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:09:44 [gpu_model_runner.py:2392] Model loading took 1.5341 GiB and 5.200435 seconds
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:09:50 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_2_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) (Worker_TP3 pid=2427667) (Worker_TP1 pid=2427663) INFO 01-04 14:09:50 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_0_0/backbone for vLLM's torch.compile
# INFO 01-04 14:09:50 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_3_0/backbone for vLLM's torch.compile
# (Worker_TP2 pid=2427665) INFO 01-04 14:09:50 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/0a0841cdb8/rank_1_0/backbone for vLLM's torch.compile
# INFO 01-04 14:09:50 [backends.py:550] Dynamo bytecode transform time: 5.62 s
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) (Worker_TP1 pid=2427663) INFO 01-04 14:09:50 [backends.py:550] Dynamo bytecode transform time: 5.63 s
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:50 [backends.py:550] Dynamo bytecode transform time: 5.60 s
# (Worker_TP0 pid=2427661) INFO 01-04 14:09:50 [backends.py:550] Dynamo bytecode transform time: 5.62 s
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) INFO 01-04 14:09:53 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.989 s
# (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) INFO 01-04 14:09:53 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.990 s
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:09:53 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.023 s
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:09:53 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.099 s
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) INFO 01-04 14:09:54 [monitor.py:34] torch.compile takes 5.63 s in total
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:09:54 [monitor.py:34] torch.compile takes 5.62 s in total
# (EngineCore_DP0 pid=2427639) (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) (Worker_TP1 pid=2427663) INFO 01-04 14:09:54 [monitor.py:34] torch.compile takes 5.62 s in total
# INFO 01-04 14:09:54 [monitor.py:34] torch.compile takes 5.60 s in total
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:55 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (Worker_TP1 pid=2427663) INFO 01-04 14:09:55 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:09:55 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:09:55 [gpu_worker.py:298] Available KV cache memory: 4.17 GiB
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:864] GPU KV cache size: 156,272 tokens
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:09:56 [kv_cache_utils.py:868] Maximum concurrency for 131,072 tokens per request: 1.19x
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:04<00:00, 15.33it/s]
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) INFO 01-04 14:10:01 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=2427639) (Worker_TP3 pid=2427667) INFO 01-04 14:10:01 [gpu_worker.py:391] Free memory on device (23.11/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=20570831872` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) INFO 01-04 14:10:01 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=2427639) (Worker_TP1 pid=2427663) INFO 01-04 14:10:01 [gpu_worker.py:391] Free memory on device (17.43/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=14476508160` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:10:01 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=2427639) (Worker_TP0 pid=2427661) INFO 01-04 14:10:01 [gpu_worker.py:391] Free memory on device (18.21/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=15317203968` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:10:01 [gpu_model_runner.py:3118] Graph capturing finished in 5 secs, took 0.91 GiB
# (EngineCore_DP0 pid=2427639) (Worker_TP2 pid=2427665) INFO 01-04 14:10:01 [gpu_worker.py:391] Free memory on device (22.23/23.55 GiB) on startup. Desired GPU memory utilization is (0.3, 7.06 GiB). Actual usage is 1.53 GiB for weight, 1.22 GiB for peak activation, 0.13 GiB for non-torch memory, and 0.91 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=3346516172` to fit into requested memory, or `--kv-cache-memory=19629210624` to fully utilize gpu memory. Current kv cache memory in use is 4481075404 bytes.
# (EngineCore_DP0 pid=2427639) INFO 01-04 14:10:01 [core.py:218] init engine (profile, create kv cache, warmup model) took 16.64 seconds
# INFO 01-04 14:10:02 [llm.py:295] Supported_tasks: ['generate']
# INFO 01-04 14:10:02 [__init__.py:36] No IOProcessor plugins requested by the model
# 0it [00:00, ?it/s]
# INFO 01-04 14:10:02 [chat_utils.py:538] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 1it [00:01,  1.37s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 2it [00:02,  1.05s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 3it [00:02,  1.11it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 4it [00:03,  1.12it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 5it [00:04,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 6it [00:05,  1.10it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 7it [00:06,  1.06it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 8it [00:07,  1.08it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 9it [00:08,  1.03s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 10it [00:09,  1.07s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 11it [00:10,  1.02it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 12it [00:11,  1.15it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 13it [00:12,  1.17it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 14it [00:12,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 15it [00:13,  1.24it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 16it [00:14,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 17it [00:15,  1.17it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 18it [00:16,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 19it [00:16,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 20it [00:17,  1.21it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 21it [00:18,  1.23it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 22it [00:19,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 23it [00:20,  1.18it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 24it [00:21,  1.15it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 25it [00:21,  1.19it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 26it [00:22,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 27it [00:23,  1.32it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 28it [00:24,  1.26it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 29it [00:24,  1.28it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 30it [00:25,  1.31it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 31it [00:26,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 32it [00:27,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 33it [00:28,  1.23it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 34it [00:28,  1.30it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 35it [00:29,  1.19it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 36it [00:30,  1.21it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 37it [00:31,  1.16it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 38it [00:32,  1.21it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 39it [00:33,  1.27it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 40it [00:33,  1.21it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 41it [00:34,  1.23it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 42it [00:35,  1.24it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 43it [00:36,  1.26it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 44it [00:36,  1.33it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 45it [00:37,  1.37it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 46it [00:38,  1.29it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 47it [00:39,  1.29it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 48it [00:39,  1.41it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 49it [00:40,  1.35it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 50it [00:41,  1.30it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 51it [00:42,  1.34it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 52it [00:42,  1.39it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 53it [00:43,  1.35it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 54it [00:44,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 55it [00:45,  1.24it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 56it [00:46,  1.26it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 57it [00:47,  1.09it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 58it [00:48,  1.02s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 59it [00:49,  1.05it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 60it [00:50,  1.12it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 61it [00:51,  1.15it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 62it [00:51,  1.19it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 63it [00:52,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 64it [00:53,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 65it [00:54,  1.11it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 66it [00:56,  1.16s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 67it [00:57,  1.21s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 68it [00:58,  1.15s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 69it [00:59,  1.07s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 70it [01:00,  1.05s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 71it [01:01,  1.02it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 72it [01:01,  1.14it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 73it [01:02,  1.10it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 74it [01:03,  1.20it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 75it [01:04,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %% [markdown]
# <!-- Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt10', 3, 0.01, 'ver5'))
# Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt10', 3, 0.01, 'ver5'))
# Process(target=task, args=('l', 4, 10, 'Y', 10, 'sys_prompt10', 5, 0.01, 'ver5')) -->
