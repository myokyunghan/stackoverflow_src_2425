# %% [markdown]
# # Experimental test 5
#
# * vllm기준으로 accuracy와 f1 score를 테스트 (vllm + llama & qwen)
# * 옵션 수정으로 인해서 결과가 다 동일하게 나오는지 확인하기 위해서 테스트 진행
# * Self_Consistency_re로 테스트
#     * fewshot 개수 : 3*3 = 9
#     * fewshot 테스트에 활용할 질문의 개수  : 30
#     * 소스코드 포함여부  : 'Y'
#     * 반복횟수 : 100회
#     * 시스템프롬프트 'sys_prompt10'
#     * self-consistency 횟수 : 5
#     * temperature : 0.01
#     * 엑셀버전 : 'ver7'
# * 이후 결과에 대해서 스코어 비교 진행
# * stop        = ["</Difficulty Level>"] 있는 버전의 점수

# %%
import lib.annotation.Self_Consistency_re as sc
# Out:
# INFO 01-06 15:19:44 [__init__.py:216] Automatically detected platform cuda.

# %%
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature, excel_ver):
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency_re(   llm_model
                            , few_shot_n
                            , test_n
                            , q_src_yn
                            , ver
                            , p_ver
                            , sc_num
                            , temperature
                            , excel_ver
                            , i)
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    task('vq',              # llm_model
        3,                # few_shot_n
        58,                # test_n(# of question for test)
        'Y',              # q_src_yn 
        5,                # iteration num
        'sys_prompt10',   # prompt ver
        5,                # self-consistency number
        0.01,             # temperature
        'ver7'            # excel_verion
        )
    print("모든 작업 완료")

# %%
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature, excel_ver):
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency_re(   llm_model
                            , few_shot_n
                            , test_n
                            , q_src_yn
                            , ver
                            , p_ver
                            , sc_num
                            , temperature
                            , excel_ver
                            , i)
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    task('vq',              # llm_model
        3,                # few_shot_n
        59,                # test_n(# of question for test)
        'Y',              # q_src_yn 
        5,                # iteration num
        'sys_prompt10',   # prompt ver
        5,                # self-consistency number
        0.01,             # temperature
        'ver7'            # excel_verion
        )
    print("모든 작업 완료")
# Out:
# Task vq_3_59_Y_sys_prompt10_5 시작
# Task vq_3_59_Y_sys_prompt10_5 실행 중: 0
# VLLM
# INFO 01-06 15:20:06 [utils.py:328] non-default args: {'tensor_parallel_size': 4, 'gpu_memory_utilization': 0.6, 'disable_log_stats': True, 'model': '/usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554'}
# INFO 01-06 15:20:13 [__init__.py:742] Resolved architecture: Qwen3ForCausalLM
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 01-06 15:20:13 [__init__.py:1815] Using max model len 262144
# INFO 01-06 15:20:14 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:15 [core.py:654] Waiting for init message from front-end.
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:15 [core.py:76] Initializing a V1 LLM engine (v0.10.2) with config: model='/usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554', speculative_config=None, tokenizer='/usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=262144, download_dir=None, load_format=auto, tensor_parallel_size=4, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=2988045) WARNING 01-06 15:20:15 [multiproc_worker_utils.py:273] Reducing Torch parallelism from 32 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:15 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0, 1, 2, 3], buffer_handle=(4, 16777216, 10, 'psm_eee9108f'), local_subscribe_addr='ipc:///tmp/9bbe5460-95dc-406b-9077-c762b017d0f0', remote_subscribe_addr=None, remote_addr_ipv6=False)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:17 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_f9003c6d'), local_subscribe_addr='ipc:///tmp/196bd9e9-434e-4924-8bae-47be6a719384', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 01-06 15:20:17 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_8afee9ad'), local_subscribe_addr='ipc:///tmp/5a7b1f0e-65e1-4980-b327-5a8176f9d763', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 01-06 15:20:17 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_17829147'), local_subscribe_addr='ipc:///tmp/9b4d3deb-c8da-4cdb-b414-03028d2afb5c', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:17 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_85c5b2d8'), local_subscribe_addr='ipc:///tmp/dd14f034-71c8-4137-a9a7-6acb38f61c14', remote_subscribe_addr=None, remote_addr_ipv6=False)
# [W106 15:20:18.516989007 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W106 15:20:18.538271118 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [pynccl.py:70] vLLM is using nccl==2.27.3
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 01-06 15:20:19 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-06 15:20:19 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 01-06 15:20:19 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [pynccl.py:70] vLLM is using nccl==2.27.3
# [W106 15:20:19.147784168 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W106 15:20:19.147866144 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3[Gloo] Rank  is connected to 3 peer ranks. 2Expected number of connected peer ranks is :  is connected to 33 peer ranks. Expected number of connected peer ranks is :
# 3
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) WARNING 01-06 15:20:19 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-06 15:20:19 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-06 15:20:19 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 01-06 15:20:19 [custom_all_reduce.py:144] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1, 2, 3], buffer_handle=(3, 4194304, 6, 'psm_fbda3a9d'), local_subscribe_addr='ipc:///tmp/e28dc587-26df-444f-be00-3d4650574a29', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [parallel_state.py:1165] rank 0 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [parallel_state.py:1165] rank 2 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 2, EP rank 2
# INFO 01-06 15:20:19 [parallel_state.py:1165] rank 1 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# INFO 01-06 15:20:19 [parallel_state.py:1165] rank 3 in world size 4 is assigned as DP rank 0, PP rank 0, TP rank 3, EP rank 3
# (EngineCore_DP0 pid=2988045) WARNING 01-06 15:20:19 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=2988045) WARNING 01-06 15:20:19 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) WARNING 01-06 15:20:19 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 01-06 15:20:19 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 0 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 1 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:19 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554...
# (Worker_TP0 pid=2988067) INFO 01-06 15:20:19 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554...
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) INFO 01-06 15:20:19 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554...
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:19 [gpu_model_runner.py:2338] Starting to load model /usr/share/d_ollama/.ollama/models/hf_model/models--Qwen--Qwen3-4B-Instruct-2507/snapshots/cdbee75f17c01a7cc42f958dc650907174af0554...
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:20 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:20 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) INFO 01-06 15:20:20 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:20 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:20 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:20 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) INFO 01-06 15:20:20 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:20 [cuda.py:362] Using Flash Attention backend on V1 engine.
# Loading safetensors checkpoint shards:   0% Completed | 0/3 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:21 [default_loader.py:268] Loading weights took 0.97 seconds
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) (Worker_TP1 pid=2988069) (Worker_TP2 pid=2988071) INFO 01-06 15:20:21 [default_loader.py:268] Loading weights took 0.98 seconds
# INFO 01-06 15:20:21 [default_loader.py:268] Loading weights took 0.96 seconds
# INFO 01-06 15:20:21 [default_loader.py:268] Loading weights took 0.96 seconds
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:21 [gpu_model_runner.py:2392] Model loading took 1.9459 GiB and 1.193057 seconds
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:21 [gpu_model_runner.py:2392] Model loading took 1.9459 GiB and 1.178244 seconds
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) (Worker_TP0 pid=2988067) INFO 01-06 15:20:21 [gpu_model_runner.py:2392] Model loading took 1.9459 GiB and 1.195508 seconds
# INFO 01-06 15:20:21 [gpu_model_runner.py:2392] Model loading took 1.9459 GiB and 1.195494 seconds
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:29 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/2851a00bc6/rank_3_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:29 [backends.py:550] Dynamo bytecode transform time: 7.66 s
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) (Worker_TP1 pid=2988069) INFO 01-06 15:20:30 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/2851a00bc6/rank_2_0/backbone for vLLM's torch.compile
# INFO 01-06 15:20:30 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/2851a00bc6/rank_1_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) INFO 01-06 15:20:30 [backends.py:550] Dynamo bytecode transform time: 7.81 s
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:30 [backends.py:550] Dynamo bytecode transform time: 7.81 s
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:30 [backends.py:539] Using cache directory: /home/mghan/.cache/vllm/torch_compile_cache/2851a00bc6/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:30 [backends.py:550] Dynamo bytecode transform time: 7.85 s
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:33 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.931 s
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) INFO 01-06 15:20:33 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.914 s
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:33 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.959 s
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:33 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.922 s
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) (Worker_TP1 pid=2988069) INFO 01-06 15:20:35 [monitor.py:34] torch.compile takes 7.81 s in total
# INFO 01-06 15:20:35 [monitor.py:34] torch.compile takes 7.81 s in total
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:35 [monitor.py:34] torch.compile takes 7.66 s in total
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:35 [monitor.py:34] torch.compile takes 7.85 s in total
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) (Worker_TP3 pid=2988073) INFO 01-06 15:20:36 [gpu_worker.py:298] Available KV cache memory: 10.62 GiB
# INFO 01-06 15:20:36 [gpu_worker.py:298] Available KV cache memory: 10.62 GiB
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:36 [gpu_worker.py:298] Available KV cache memory: 10.62 GiB
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:36 [gpu_worker.py:298] Available KV cache memory: 10.62 GiB
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:864] GPU KV cache size: 309,328 tokens
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:868] Maximum concurrency for 262,144 tokens per request: 1.18x
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:864] GPU KV cache size: 309,328 tokens
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:868] Maximum concurrency for 262,144 tokens per request: 1.18x
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:864] GPU KV cache size: 309,328 tokens
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:868] Maximum concurrency for 262,144 tokens per request: 1.18x
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:864] GPU KV cache size: 309,328 tokens
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:37 [kv_cache_utils.py:868] Maximum concurrency for 262,144 tokens per request: 1.18x
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:05<00:00, 11.77it/s]
# (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) INFO 01-06 15:20:43 [gpu_model_runner.py:3118] Graph capturing finished in 7 secs, took 1.18 GiB
# (EngineCore_DP0 pid=2988045) (EngineCore_DP0 pid=2988045) (Worker_TP1 pid=2988069) (Worker_TP2 pid=2988071) INFO 01-06 15:20:43 [gpu_worker.py:391] Free memory on device (17.43/23.55 GiB) on startup. Desired GPU memory utilization is (0.6, 14.13 GiB). Actual usage is 1.95 GiB for weight, 1.43 GiB for peak activation, 0.13 GiB for non-torch memory, and 1.18 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=9979443609` to fit into requested memory, or `--kv-cache-memory=13524377600` to fully utilize gpu memory. Current kv cache memory in use is 11403409817 bytes.
# INFO 01-06 15:20:43 [gpu_model_runner.py:3118] Graph capturing finished in 7 secs, took 1.18 GiB
# (EngineCore_DP0 pid=2988045) (Worker_TP2 pid=2988071) (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:43 [gpu_worker.py:391] Free memory on device (22.23/23.55 GiB) on startup. Desired GPU memory utilization is (0.6, 14.13 GiB). Actual usage is 1.95 GiB for weight, 1.43 GiB for peak activation, 0.13 GiB for non-torch memory, and 1.18 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=9979443609` to fit into requested memory, or `--kv-cache-memory=18677080064` to fully utilize gpu memory. Current kv cache memory in use is 11403409817 bytes.
# INFO 01-06 15:20:43 [gpu_model_runner.py:3118] Graph capturing finished in 7 secs, took 1.18 GiB
# (EngineCore_DP0 pid=2988045) (Worker_TP0 pid=2988067) INFO 01-06 15:20:43 [gpu_worker.py:391] Free memory on device (18.21/23.55 GiB) on startup. Desired GPU memory utilization is (0.6, 14.13 GiB). Actual usage is 1.95 GiB for weight, 1.43 GiB for peak activation, 0.13 GiB for non-torch memory, and 1.18 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=9979443609` to fit into requested memory, or `--kv-cache-memory=14365073408` to fully utilize gpu memory. Current kv cache memory in use is 11403409817 bytes.
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:43 [gpu_model_runner.py:3118] Graph capturing finished in 7 secs, took 1.18 GiB
# (EngineCore_DP0 pid=2988045) (Worker_TP3 pid=2988073) INFO 01-06 15:20:44 [gpu_worker.py:391] Free memory on device (23.11/23.55 GiB) on startup. Desired GPU memory utilization is (0.6, 14.13 GiB). Actual usage is 1.95 GiB for weight, 1.43 GiB for peak activation, 0.13 GiB for non-torch memory, and 1.18 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=9979443609` to fit into requested memory, or `--kv-cache-memory=19618701312` to fully utilize gpu memory. Current kv cache memory in use is 11403409817 bytes.
# (EngineCore_DP0 pid=2988045) INFO 01-06 15:20:44 [core.py:218] init engine (profile, create kv cache, warmup model) took 22.07 seconds
# INFO 01-06 15:20:45 [llm.py:295] Supported_tasks: ['generate']
# INFO 01-06 15:20:45 [__init__.py:36] No IOProcessor plugins requested by the model
# 0it [00:00, ?it/s]
# INFO 01-06 15:20:45 [chat_utils.py:538] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 1it [00:06,  6.18s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 2it [00:06,  2.96s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 3it [00:07,  1.92s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 4it [00:08,  1.44s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 5it [00:09,  1.19s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 6it [00:12,  1.94s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 7it [00:12,  1.40s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 8it [00:12,  1.03s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 9it [00:13,  1.28it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 10it [00:13,  1.61it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 11it [00:18,  1.87s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 12it [00:18,  1.39s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 13it [00:18,  1.06s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 14it [00:19,  1.20it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 15it [00:19,  1.49it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 16it [00:24,  2.02s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 17it [00:24,  1.50s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 18it [00:25,  1.14s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 19it [00:25,  1.12it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 20it [00:25,  1.38it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 21it [00:30,  1.94s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 22it [00:30,  1.44s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 23it [00:31,  1.10s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 24it [00:31,  1.16it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 25it [00:31,  1.45it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 26it [00:36,  1.81s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 27it [00:36,  1.35s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 28it [00:36,  1.03s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 29it [00:36,  1.23it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 30it [00:37,  1.54it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 31it [00:42,  2.15s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 32it [00:43,  1.60s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 33it [00:43,  1.23s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 34it [00:43,  1.05it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 35it [00:44,  1.30it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 36it [00:49,  1.98s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 37it [00:49,  1.48s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 38it [00:49,  1.11s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 39it [00:49,  1.15it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 40it [00:50,  1.44it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 41it [00:56,  2.50s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 42it [00:57,  1.86s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 43it [00:57,  1.41s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 44it [00:57,  1.09s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 45it [00:58,  1.14it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 46it [01:02,  1.93s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 47it [01:03,  1.44s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 48it [01:03,  1.09s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 49it [01:03,  1.17it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 50it [01:03,  1.46it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 51it [01:08,  1.95s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 52it [01:09,  1.45s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 53it [01:09,  1.09s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 54it [01:09,  1.19it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 55it [01:09,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 56it [01:14,  1.75s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 57it [01:14,  1.30s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 58it [01:14,  1.00it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 59it [01:14,  1.27it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 60it [01:15,  1.58it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 61it [01:20,  1.99s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 62it [01:20,  1.48s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 63it [01:21,  1.14s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 64it [01:21,  1.13it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 65it [01:21,  1.41it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 66it [01:26,  1.85s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 67it [01:26,  1.38s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 68it [01:26,  1.05s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 69it [01:27,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 70it [01:27,  1.48it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 71it [01:31,  1.83s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 72it [01:32,  1.37s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 73it [01:32,  1.04s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 74it [01:32,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 75it [01:33,  1.52it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 76it [01:36,  1.53s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 77it [01:36,  1.14s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 78it [01:37,  1.14it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 79it [01:37,  1.46it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 80it [01:37,  1.82it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 81it [01:42,  1.88s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 82it [01:42,  1.41s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 83it [01:43,  1.07s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 84it [01:43,  1.19it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 85it [01:43,  1.48it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 86it [01:47,  1.61s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 87it [01:47,  1.22s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 88it [01:48,  1.07it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 89it [01:48,  1.38it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 90it [01:48,  1.71it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 91it [01:53,  1.82s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 92it [01:53,  1.36s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 93it [01:53,  1.04s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 94it [01:54,  1.21it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 95it [01:54,  1.50it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 96it [02:00,  2.20s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 97it [02:00,  1.66s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 98it [02:01,  1.26s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 99it [02:01,  1.02it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 100it [02:01,  1.27it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 101it [02:07,  2.20s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 102it [02:07,  1.64s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 103it [02:07,  1.24s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 104it [02:08,  1.04it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 105it [02:08,  1.28it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 106it [02:12,  1.76s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 107it [02:12,  1.31s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 108it [02:13,  1.01s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 109it [02:13,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 110it [02:13,  1.53it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 111it [02:17,  1.51s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 112it [02:17,  1.14s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 113it [02:17,  1.13it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 114it [02:18,  1.42it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 115it [02:18,  1.75it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 116it [02:22,  1.66s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 117it [02:22,  1.25s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 118it [02:23,  1.05it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 119it [02:23,  1.30it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 120it [02:23,  1.60it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 121it [02:27,  1.70s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 122it [02:28,  1.28s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 123it [02:28,  1.01it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 124it [02:28,  1.28it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 125it [02:29,  1.58it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 126it [02:34,  2.15s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 127it [02:35,  1.61s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 128it [02:35,  1.23s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 129it [02:35,  1.04it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 130it [02:36,  1.29it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 131it [02:40,  1.79s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 132it [02:40,  1.34s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 133it [02:40,  1.02s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 134it [02:41,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 135it [02:41,  1.54it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# 211it [04:09,  1.96s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 212it [04:10,  1.46s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 213it [04:10,  1.13s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 214it [04:10,  1.12it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 215it [04:11,  1.38it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 216it [04:17,  2.35s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 217it [04:17,  1.75s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 218it [04:18,  1.34s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 219it [04:18,  1.05s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 220it [04:18,  1.19it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 221it [04:23,  2.01s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 222it [04:23,  1.51s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 223it [04:24,  1.24s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 224it [04:25,  1.04s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 225it [04:25,  1.10it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 226it [04:30,  2.23s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 227it [04:31,  1.65s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 228it [04:31,  1.25s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 229it [04:31,  1.04it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 230it [04:32,  1.31it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 231it [04:35,  1.51s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 232it [04:35,  1.13s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 233it [04:35,  1.14it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 234it [04:36,  1.44it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 235it [04:36,  1.76it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 236it [04:40,  1.68s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 237it [04:41,  1.28s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 238it [04:41,  1.01s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 239it [04:41,  1.23it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 240it [04:42,  1.51it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 241it [04:46,  1.75s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 242it [04:46,  1.32s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 243it [04:47,  1.01s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 244it [04:47,  1.25it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 245it [04:47,  1.53it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 246it [04:52,  1.95s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 247it [04:53,  1.46s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 248it [04:53,  1.12s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 249it [04:53,  1.12it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 250it [04:54,  1.39it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 251it [04:59,  2.00s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 252it [04:59,  1.51s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 253it [04:59,  1.15s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 254it [05:00,  1.10it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 255it [05:00,  1.36it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 256it [05:04,  1.77s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 257it [05:04,  1.34s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 258it [05:05,  1.04s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 259it [05:05,  1.22it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 260it [05:05,  1.51it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 261it [05:09,  1.69s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 262it [05:10,  1.28s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 263it [05:10,  1.02it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 264it [05:10,  1.29it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 265it [05:11,  1.58it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 266it [05:14,  1.42s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 267it [05:14,  1.07s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 268it [05:14,  1.20it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 269it [05:15,  1.52it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 270it [05:15,  1.87it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 271it [05:21,  2.18s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 272it [05:21,  1.64s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 273it [05:22,  1.25s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 274it [05:22,  1.02it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 275it [05:22,  1.26it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 276it [05:27,  2.00s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 277it [05:28,  1.50s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 278it [05:28,  1.14s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 279it [05:28,  1.14it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 280it [05:28,  1.43it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 281it [05:33,  1.91s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 282it [05:33,  1.43s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 283it [05:34,  1.10s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 284it [05:34,  1.16it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 285it [05:34,  1.44it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 286it [05:40,  2.27s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 287it [05:41,  1.71s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 288it [05:41,  1.31s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 289it [05:41,  1.02s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 290it [05:42,  1.21it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 291it [05:46,  1.90s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 292it [05:47,  1.43s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 293it [05:47,  1.09s/it]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 294it [05:47,  1.16it/s]
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 295it [05:47,  1.18s/it]
# Task vq_3_59_Y_sys_prompt10_5 완료
# 모든 작업 완료

# %% [markdown]
# <!-- Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt10', 3, 0.01, 'ver5'))
# Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt10', 3, 0.01, 'ver5'))
# Process(target=task, args=('l', 4, 10, 'Y', 10, 'sys_prompt10', 5, 0.01, 'ver5')) -->

# %%
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature, excel_ver):
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency(   llm_model
                            , few_shot_n
                            , test_n
                            , q_src_yn
                            , ver
                            , p_ver
                            , sc_num
                            , temperature
                            , excel_ver
                            , i)
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    task('vl',              # llm_model
        3,                # few_shot_n
        60,                # test_n(# of question for test)
        'Y',              # q_src_yn 
        100,                # iteration num
        'sys_prompt10',   # prompt ver
        5,                # self-consistency number
        0.01,             # temperature
        'ver7'            # excel_verion
        )
    print("모든 작업 완료")
