# %%
import sys
print(sys.executable)
# Out:
# /home/mghan/sopjt/git/venv_stackoverflow_src/bin/python

# %%
# !{sys.executable} -m pip install -e .
# Out:
# Obtaining file:///home/mghan/sopjt/git/stackoverflow_src_2425
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for stackoverflow-src-2425
# ...

# %%
import config
print(config.__file__)
# Out:
# /home/mghan/sopjt/git/stackoverflow_src_2425/config/__init__.py

# %%
import config.config as conf
print(conf.__file__)
# Out:
# /home/mghan/sopjt/git/stackoverflow_src_2425/config/config.py
