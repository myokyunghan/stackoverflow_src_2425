# %%
import sys, os
p = os.path.abspath('..')
# p = p+r'\config'
sys.path.insert(1, p)

# %%
import lib.annotation.D_Annotation as da
import tqdm

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 실행 중: {i}")
#         da.D_Annotation(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 완료")

# if __name__ == "__main__":
#     process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt2'))
#     process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt2'))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt2'))
#     process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt2'))

#     process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt2'))
#     process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt2'))
    
#     process1.start()
#     process2.start()
#     process3.start()
#     process4.start()
#     process5.start()
#     process6.start()
    
#     process1.join()
#     process2.join()
#     process3.join()
#     process4.join()
#     process5.join()
#     process6.join()
#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 실행 중: {i}")
#         da.D_Annotation(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 완료")

# if __name__ == "__main__":
#     process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt3'))
#     process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt3'))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt3'))
#     process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt3'))

#     process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt3'))
#     process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt3'))
    
#     process1.start()
#     process2.start()
#     process3.start()
#     process4.start()
#     process5.start()
#     process6.start()
    
#     process1.join()
#     process2.join()
#     process3.join()
#     process4.join()
#     process5.join()
#     process6.join()
#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 실행 중: {i}")
#         da.D_Annotation(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 완료")

# if __name__ == "__main__":
#     process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt4'))
#     process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt4'))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt4'))
#     process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt4'))

#     process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt4'))
#     process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt4'))
    
#     process1.start()
#     process2.start()
#     process3.start()
#     process4.start()
#     process5.start()
#     process6.start()
    
#     process1.join()
#     process2.join()
#     process3.join()
#     process4.join()
#     process5.join()
#     process6.join()
#     print("모든 작업 완료")

# %%
import lib.annotation.Self_Consistency as sc
import tqdm

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
#         sc.Self_Consistency(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver
#                         , sc_num)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

# if __name__ == "__main__":
#     process3 = Process(target=task, args=('l', 2, 5, 'Y', 5, 'sys_prompt5', 5))
#     process4 = Process(target=task, args=('l', 2, 5, 'N', 5, 'sys_prompt5', 5))


#     process3.start()
#     process4.start()


#     process3.join()
#     process4.join()

#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
#         sc.Self_Consistency(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver
#                         , sc_num)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

# if __name__ == "__main__":
#     process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt6', 5))
#     process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt6', 5))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt6', 5))
#     process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt6', 5))

#     process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt6', 5))
#     process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt6', 5))
    
#     process1.start()
#     process2.start()
#     process3.start()
#     process4.start()
#     process5.start()
#     process6.start()
    
#     process1.join()
#     process2.join()
#     process3.join()
#     process4.join()
#     process5.join()
#     process6.join()
#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
#         sc.Self_Consistency(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver
#                         , sc_num)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

# if __name__ == "__main__":
#     # process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt7', 5))

#     process3 = Process(target=task, args=('l', 4, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt7', 5))

#     # process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt7', 5))
    
#     # process1.start()
#     # process2.start()
#     process3.start()
#     # process4.start()
#     # process5.start()
#     # process6.start()
    
#     # process1.join()
#     # process2.join()
#     process3.join()
#     # process4.join()
#     # process5.join()
#     # process6.join()
#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
#         sc.Self_Consistency(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver
#                         , sc_num)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

# if __name__ == "__main__":
#     # process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt7', 5))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 20, 'sys_prompt4', 5))
#     # process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt7', 5))

#     # process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt7', 5))
    
#     # process1.start()
#     # process2.start()
#     process3.start()
#     # process4.start()
#     # process5.start()
#     # process6.start()
    
#     # process1.join()
#     # process2.join()
#     process3.join()
#     # process4.join()
#     # process5.join()
#     # process6.join()
#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num}_{temperature} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num}_{temperature} 실행 중: {i}")
#         sc.Self_Consistency(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver
#                         , sc_num
#                         , temperature
#                         )  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

# if __name__ == "__main__":
#     # process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt7', 5))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 20, 'sys_prompt4', 5, 0))
#     # process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt7', 5))

#     # process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt7', 5))
#     # process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt7', 5))
    
#     # process1.start()
#     # process2.start()
#     process3.start()
#     # process4.start()
#     # process5.start()
#     # process6.start()
    
#     # process1.join()
#     # process2.join()
#     process3.join()
#     # process4.join()
#     # process5.join()
#     # process6.join()
#     print("모든 작업 완료")

# %%
from multiprocessing import Process
    
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature):

    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num}_{temperature} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num}_{temperature} 실행 중: {i}")
        sc.Self_Consistency(  llm_model
                        , few_shot_n
                        , test_n
                        , q_src_yn
                        , i
                        , p_ver
                        , sc_num
                        , temperature
                        )  
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":
    # process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt7', 5))
    # process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt7', 5))

    process3 = Process(target=task, args=('c', 3, 10, 'Y', 5, 'sys_prompt8', 5, 0.01))
    # process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt7', 5))

    # process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt7', 5))
    # process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt7', 5))
    
    # process1.start()
    # process2.start()
    process3.start()
    # process4.start()
    # process5.start()
    # process6.start()
    
    # process1.join()
    # process2.join()
    process3.join()
    # process4.join()
    # process5.join()
    # process6.join()
    print("모든 작업 완료")
# Out:
# Task c_3_10_Y_sys_prompt8_5_0.01 시작
# Task c_3_10_Y_sys_prompt8_5_0.01 실행 중: 0
# 50it [09:18, 11.18s/it]
# Task c_3_10_Y_sys_prompt8_5_0.01 실행 중: 1
# 50it [10:21, 12.43s/it]
# Task c_3_10_Y_sys_prompt8_5_0.01 실행 중: 2
# 50it [09:57, 11.94s/it]
# Task c_3_10_Y_sys_prompt8_5_0.01 실행 중: 3
# 50it [10:54, 13.08s/it]
# Task c_3_10_Y_sys_prompt8_5_0.01 실행 중: 4
# 50it [10:29, 12.59s/it]
# Task c_3_10_Y_sys_prompt8_5 완료
# 모든 작업 완료

# %%
from multiprocessing import Process
    
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num, temperature):

    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num}_{temperature} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num}_{temperature} 실행 중: {i}")
        sc.Self_Consistency(  llm_model
                        , few_shot_n
                        , test_n
                        , q_src_yn
                        , i
                        , p_ver
                        , sc_num
                        , temperature
                        )  
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":
    # process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt7', 5))
    # process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt7', 5))

    process3 = Process(target=task, args=('c', 3, 10, 'Y', 5, 'sys_prompt8', 5, 0.01))
    # process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt7', 5))

    # process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt7', 5))
    # process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt7', 5))
    
    # process1.start()
    # process2.start()
    process3.start()
    # process4.start()
    # process5.start()
    # process6.start()
    
    # process1.join()
    # process2.join()
    process3.join()
    # process4.join()
    # process5.join()
    # process6.join()
    print("모든 작업 완료")
# Out:
# Help on method chat in module ollama._client:
#
# chat(model: str = '', messages: Optional[Sequence[ollama._types.Message]] = None, tools: Optional[Sequence[ollama._types.Tool]] = None, stream: bool = False, format: Literal['', 'json'] = '', options: Optional[ollama._types.Options] = None, keep_alive: Union[float, str, NoneType] = None) -> Union[Mapping[str, Any], collections.abc.Iterator[Mapping[str, Any]]] method of ollama._client.Client instance
#     Create a chat response using the requested model.
#
#     Raises `RequestError` if a model is not provided.
#
#     Raises `ResponseError` if the request could not be fulfilled.
#
#     Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
