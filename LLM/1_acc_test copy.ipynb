# %%
import sys, os
p = os.path.abspath('..')
# p = p+r'\config'
sys.path.insert(1, p)

# %%
import lib.annotation.D_Annotation as da
import tqdm
import lib.annotation.Self_Consistency as sc
import tqdm

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 실행 중: {i}")
#         da.D_Annotation(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver} 완료")

# if __name__ == "__main__":
#     process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt1'))
#     process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt1'))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt1'))
#     process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt1'))

#     process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt1'))
#     process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt1'))
    
#     process1.start()
#     process2.start()
#     process3.start()
#     process4.start()
#     process5.start()
#     process6.start()
    
#     process1.join()
#     process2.join()
#     process3.join()
#     process4.join()
#     process5.join()
#     process6.join()
#     print("모든 작업 완료")

# %%
# from multiprocessing import Process
    
# def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
#     for i in range(ver):
#         print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
#         sc.Self_Consistency(  llm_model
#                         , few_shot_n
#                         , test_n
#                         , q_src_yn
#                         , i
#                         , p_ver
#                         , sc_num)  
    
#     print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

# if __name__ == "__main__":
#     process1 = Process(target=task, args=('l', 1, 10, 'Y', 10, 'sys_prompt4', 5))
#     process2 = Process(target=task, args=('l', 1, 10, 'N', 10, 'sys_prompt4', 5))

#     process3 = Process(target=task, args=('l', 2, 10, 'Y', 10, 'sys_prompt4', 5))
#     process4 = Process(target=task, args=('l', 2, 10, 'N', 10, 'sys_prompt4', 5))

#     process5 = Process(target=task, args=('l', 3, 10, 'Y', 10, 'sys_prompt4', 5))
#     process6 = Process(target=task, args=('l', 3, 10, 'N', 10, 'sys_prompt4', 5))
    
#     process1.start()
#     process2.start()
#     process3.start()
#     process4.start()
#     process5.start()
#     process6.start()
    
#     process1.join()
#     process2.join()
#     process3.join()
#     process4.join()
#     process5.join()
#     process6.join()
#     print("모든 작업 완료")

# %%
from multiprocessing import Process
    
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency(  llm_model
                        , few_shot_n
                        , test_n
                        , q_src_yn
                        , i
                        , p_ver
                        , sc_num)  
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    process3 = Process(target=task, args=('c', 2, 10, 'Y', 10, 'sys_prompt4', 5))
    

    process3.start()
    
    process3.join()
    print("모든 작업 완료")
# Out:
# Task c_2_10_Y_sys_prompt4_5 시작
# Task c_2_10_Y_sys_prompt4_5 실행 중: 0
# 50it [06:10,  7.40s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 1
# 50it [06:35,  7.92s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 2
# 50it [07:00,  8.41s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 3
# 50it [07:24,  8.88s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 4
# 50it [07:37,  9.15s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 5
# 50it [07:22,  8.86s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 6
# 50it [07:09,  8.59s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 7
# 50it [07:16,  8.73s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 8
# 50it [06:56,  8.33s/it]
# Task c_2_10_Y_sys_prompt4_5 실행 중: 9
# 50it [06:51,  8.23s/it]
# Task c_2_10_Y_sys_prompt4_5 완료
# 모든 작업 완료

# %%
from multiprocessing import Process
    
def task(llm_model, few_shot_n, test_n, q_src_yn, ver, p_ver, sc_num):

    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 시작")
    for i in range(ver):
        print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 실행 중: {i}")
        sc.Self_Consistency(  llm_model
                        , few_shot_n
                        , test_n
                        , q_src_yn
                        , i
                        , p_ver
                        , sc_num)  
    
    print(f"Task {llm_model}_{few_shot_n}_{test_n}_{q_src_yn}_{p_ver}_{sc_num} 완료")

if __name__ == "__main__":


    process3 = Process(target=task, args=('c', 2, 10, 'Y', 10, 'sys_prompt7', 5))
    

    process3.start()
    
    process3.join()
    print("모든 작업 완료")
