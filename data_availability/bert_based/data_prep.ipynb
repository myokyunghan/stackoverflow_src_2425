# %%
import sys, os
p = os.path.abspath('../..')
pp = os.path.abspath('../../..')
ppp = os.path.abspath('../../visualization')
sys.path.insert(1, p)
sys.path.insert(1, pp)
sys.path.insert(1, ppp)

# %%
import psycopg2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import time
import pprint
from itertools import combinations
import pickle
import config.config as conf
import string
import re
import config.config as conf
from constants import CONSTANTS
import json

# %%
# lang='python'
lang='python'

# %%
conn = psycopg2.connect(dbname  =   conf.database_user['dbname'], 
                        user    =   conf.database_user['user'], 
                        password=   conf.database_user['password'], 
                        host    =   conf.database_user['host'], 
                        port    =   conf.database_user['port'])

# %%
lang_tag_dict = {'python' : 'python',
                'cpp': 'c++',
                'java':'java',
                'vba':'vba'
                }

# %%
for idx in range(len(CONSTANTS.monthly_timestamps)-1):
    st_dt = CONSTANTS.monthly_timestamps[idx].replace('.','-')
    end_dt = CONSTANTS.monthly_timestamps[idx+1].replace('.','-')

    cur = conn.cursor()
    sql = f"""select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<{lang}>%' and p.creationdate >=  '{str(st_dt)}'  and p.creationdate < '{str(end_dt)}' """
    print(sql)
    cur.execute(sql)
    inserted_data = cur.fetchall()
    type(inserted_data)
    cur.close()
    

    dict_q = [{ 'id' : x[0], 
                'creationdate' : x[1].isoformat(),
                'title' : x[2],
                'tags' : x[3],
                'body' : x[4]
            } for x in inserted_data]
    # json_str = json.dumps(dict_q, default=str, ensure_ascii=False, indent=2)

    with open(f"../../../so_pjt_src/data/snapshot2/questions/{lang}/{idx}.json", "w", encoding="utf-8") as f:
        json.dump(dict_q, f, ensure_ascii=False, indent=2)
# Out:
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2021-11-30'  and p.creationdate < '2021-12-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2021-12-31'  and p.creationdate < '2022-01-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-01-31'  and p.creationdate < '2022-02-28'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-02-28'  and p.creationdate < '2022-03-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-03-31'  and p.creationdate < '2022-04-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-04-30'  and p.creationdate < '2022-05-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-05-31'  and p.creationdate < '2022-06-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-06-30'  and p.creationdate < '2022-07-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-07-31'  and p.creationdate < '2022-08-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-08-31'  and p.creationdate < '2022-09-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-09-30'  and p.creationdate < '2022-10-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-10-31'  and p.creationdate < '2022-11-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-11-30'  and p.creationdate < '2022-12-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2022-12-31'  and p.creationdate < '2023-01-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-01-31'  and p.creationdate < '2023-02-28'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-02-28'  and p.creationdate < '2023-03-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-03-31'  and p.creationdate < '2023-04-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-04-30'  and p.creationdate < '2023-05-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-05-31'  and p.creationdate < '2023-06-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-06-30'  and p.creationdate < '2023-07-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-07-31'  and p.creationdate < '2023-08-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-08-31'  and p.creationdate < '2023-09-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-09-30'  and p.creationdate < '2023-10-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-10-31'  and p.creationdate < '2023-11-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-11-30'  and p.creationdate < '2023-12-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2023-12-31'  and p.creationdate < '2024-01-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-01-31'  and p.creationdate < '2024-02-28'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-02-28'  and p.creationdate < '2024-03-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-03-31'  and p.creationdate < '2024-04-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-04-30'  and p.creationdate < '2024-05-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-05-31'  and p.creationdate < '2024-06-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-06-30'  and p.creationdate < '2024-07-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-07-31'  and p.creationdate < '2024-08-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-08-31'  and p.creationdate < '2024-09-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-09-30'  and p.creationdate < '2024-10-31'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-10-31'  and p.creationdate < '2024-11-30'
# select p.id, p.creationdate, p.title, p.tags, p2.body from public_for_2324.posts p , public_for_2324.postsbody p2 where p.id = p2.id and p.posttypeid = '1' and p.tags like '%<python>%' and p.creationdate >=  '2024-11-30'  and p.creationdate < '2024-12-31'

# %%
conn.close()
